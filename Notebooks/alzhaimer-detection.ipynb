# %% [markdown]
# <div style ="font-family:Trebuchet MS; background-color : #f8f0fa; border-left: 5px solid #1b4332; padding: 12px; border-radius: 50px 50px;">
#     <h2 style="color: #1b4332; font-size: 48px; text-align: center;">
#         <b> Alzhaimers detection</b>
#         <hr style="border-top: 2px solid #264653;">
#     </h2>
#     <h3 style="font-size: 14px; color: #264653; text-align: left; "><strong> I hope this is very helpful. let's started .😊🌟</strong></h3>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Outline🌟🔻
# </h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <ul>
#         <li>🔻🌟Overview about the project 📋</li>
#         <li>🔻🌟Import libraries 📂</li>
#         <li>🔻🌟 Loading the dataset 🌟</li>
#         <li>🔻🌟 Data Visualization 🌟🔻</li>
#         <li>🔻🌟 Data preprocessing & Data Augmentation 🌟🔻</li>
#         <li>🔻🌟Building CNN Model 🚊</li>
#         <li>🔻🌟Testing & Save the model 🎯</li>
#         <li>🔻🌟 analysis</li>
#     </ul>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Overview about the project 🌟🔻</h1>

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://mir-s3-cdn-cf.behance.net/project_modules/disp/27a60822498053.56313a34a797a.gif">

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <Strong>Objective:</Strong>
#     <hr>
#     <p>The goal of this project is to develop a machine learning model that can accurately classify MRI images into four categories related to Alzheimer's disease:</p>
#     <li>Mild Demented</li>
#     <li>Moderate Demented</li>
#     <li>Non Demented</li>
#     <li>Very Mild Demented</li>
#     <p>The dataset is hand-collected from various websites, with each label verified for accuracy.</p>
#     <Strong>What is Alzheimer:</Strong>
#     <hr>
#     <p>Alzheimer's disease is a progressive neurological disorder that leads to memory loss, cognitive decline, and changes in behavior. It is the most common cause of dementia, affecting a person's ability to think, remember, and carry out daily activities. Symptoms typically start with mild memory issues and can worsen over time, eventually affecting language, reasoning, and the ability to perform tasks. The exact cause is still not fully understood, but it involves a combination of genetic, environmental, and lifestyle factors. There is currently no cure, but treatments are available to help manage symptoms.<p>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Import libraries 🌟🔻</h1>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

import os

import pickle

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# deep learning
import tensorflow as tf
import keras
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, BatchNormalization, Input

from tensorflow.keras.layers import RandomRotation, RandomContrast, RandomZoom, RandomFlip, RandomTranslation

from tensorflow.keras.preprocessing import image_dataset_from_directory

# Training Model callbacks

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# %matplotlib inline
plt.style.use('ggplot')
# Out:
# 2024-07-28 00:54:55.566875: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-28 00:54:55.566991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-28 00:54:55.712558: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# general parameters 

plt.rcParams["figure.figsize"] = (18, 9)
plt.rcParams.update({'font.size': 15})

# %%
# Check if GPU is available
print(f'Tensorflow Version: {tf.__version__}')
print("GPU Available:", tf.config.list_physical_devices('GPU')[0])
# Out:
# Tensorflow Version: 2.15.0
# GPU Available: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Loading the dataset 🌟🔻</h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
# <p>Keras provides tools in keras.utils to help you load raw data from your storage and convert it into a tf.data.Dataset object, which is ideal for training machine learning models efficiently.</p>
# <p>These loading utilities can work alongside preprocessing layers to modify your dataset before you start training.</p>
# <p>For example, if you have a training data structure with 10 folders (each representing a different class) and each folder contains 10,000 images, you would organize your files as follows:<p>
#
# training_data/
#    ├── class_a/
#    │     ├── a_image_1.jpg
#    │     ├── a_image_2.jpg
#    ├── class_b/
#    │     ├── b_image_1.jpg
#    │     ├── b_image_2.jpg
#    └── etc.
# <p>In this setup, you aim to train a classifier that will learn to identify the category of each image.</p>
# </div>

# %%
strategy = tf.distribute.MirroredStrategy()
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [176, 208]

# %%
path_train = "/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train"
path_test = "/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test"

train_ds = image_dataset_from_directory(
    path_train,
    validation_split = 0.2,
    subset = "training",
    seed = 1337,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
)

val_ds = image_dataset_from_directory(
    path_test,
    validation_split = 0.2,
    subset = "validation",
    seed = 1337,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 1279 files belonging to 4 classes.
# Using 255 files for validation.

# %%
class_names = ['MildDementia', 'ModerateDementia', 'NonDementia', 'VeryMildDementia']
train_ds.class_names = class_names
val_ds.class_names = class_names

NUM_CLASSES = len(class_names)
print(NUM_CLASSES)
# Out:
# 4

# %%
# Extract labels from datasets
def extract_labels(dataset):
    labels = []
    for _, label_batch in dataset:
        labels.extend(label_batch.numpy())
    return labels

train_labels = extract_labels(train_ds)
val_labels = extract_labels(val_ds)

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Data Visualization 🌟🔻</h1>

# %%
def plot_pie_chart(distribution, title, ax):
    distribution_series = pd.Series(distribution)
    counts = distribution_series.value_counts()
    ax.pie(counts, labels=[f'{label} : {count}' for label, count in zip(counts.index, counts)],
           autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"))
    ax.axis('equal')  
    ax.set_title(title,pad=20)

fig, axes = plt.subplots(1, 2, figsize=(18, 6))

plot_pie_chart(train_labels, "Training Data Distribution", axes[0])
plot_pie_chart(val_labels, "Testing Data Distribution", axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## This is an umbalanced data wi will handel this problem in the future

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):  # Take one batch from the dataset
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(train_ds.class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟Data Augmentation 🌟🔻</h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <hr>
#     <p>
# <code>What is Data Augmentation</code>
# <p>is a technique used to prevent overfitting and handling the imbalance in a dataset in machine learning by artificially increasing the size of a training dataset. This involves applying small modifications to the existing data, which helps the model learn to recognize variations in the data while keeping the labels the same. Common transformation methods include converting images to grayscale, flipping them horizontally or vertically, cropping them randomly, adjusting colors, and rotating them. By using these methods, you can significantly increase the number of training examples, making your model more robust and improving its performance.</p>
#     <code>What is One-hot encoding</code>
#     <p>when dealing with categorical (non-numeric) data, we need to use a method called one-hot encoding. This process transforms categorical data into a numerical format that a model can understand. One-hot encoding creates binary columns for each category, making it clear which category a particular observation belongs to. </p>
# </div>

# %%
# data_augmentation = Sequential([
#     RandomFlip("horizontal"),
#     RandomRotation(0.02, fill_mode='constant'),
#     RandomContrast(0.1),
#     RandomZoom(height_factor=0.01, width_factor=0.05),
#     RandomTranslation(height_factor=0.0015, width_factor=0.0015, fill_mode='constant'),
# ])

# # Training augmentation and normalization
# def preprocess_train(image, label):
#     # Apply data augmentation and Normalize
#     image = data_augmentation(image) / 255.0
#     return image, label

# # For test dataset only applying normalization
# def preprocess_test(image, label):
#     return image / 255.0, label

# # Apply transformation to training and testing datasets
# train_ds = train_ds.map(preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
# test_ds = val_ds.map(preprocess_test, num_parallel_calls=tf.data.AUTOTUNE)

def one_hot_label(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label

train_ds = train_ds.map(one_hot_label, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(one_hot_label, num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻  Building CNN Model 🚊🔻</h1>

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block



def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block


def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(*IMAGE_SIZE, 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model


with strategy.scope():
    model = build_model()

    METRICS = [tf.keras.metrics.AUC(name='auc')]
    
    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )

# %%
# Callbacks 
    
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.keras",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Training  🌟🔻</h1>

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
    epochs=100
)
# Out:
# Epoch 1/100
# 2024-07-28 00:55:28.394563: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_7_1/dropout_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 30s 70ms/step - auc: 0.7170 - loss: 1.3483 - val_auc: 0.7792 - val_loss: 2.0410 - learning_rate: 0.0100
# Epoch 2/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8205 - loss: 0.9597 - val_auc: 0.7427 - val_loss: 4.8415 - learning_rate: 0.0089
# Epoch 3/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 17s 64ms/step - auc: 0.8244 - loss: 0.9594 - val_auc: 0.8313 - val_loss: 1.2533 - learning_rate: 0.0079
# Epoch 4/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - auc: 0.8361 - loss: 0.9256 - val_auc: 0.8516 - val_loss: 1.1369 - learning_rate: 0.0071
# Epoch 5/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - auc: 0.8388 - loss: 0.9204 - val_auc: 0.8517 - val_loss: 1.2267 - learning_rate: 0.0063
# Epoch 6/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8445 - loss: 0.9045 - val_auc: 0.7885 - val_loss: 2.4378 - learning_rate: 0.0056
# Epoch 7/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8417 - loss: 0.9005 - val_auc: 0.6641 - val_loss: 1.1975 - learning_rate: 0.0050
# Epoch 8/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - auc: 0.8493 - loss: 0.8868 - val_auc: 0.8079 - val_loss: 0.9659 - learning_rate: 0.0045
# Epoch 9/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - auc: 0.8490 - loss: 0.8821 - val_auc: 0.5714 - val_loss: 1.5397 - learning_rate: 0.0040
# Epoch 10/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - auc: 0.8537 - loss: 0.8659 - val_auc: 0.8544 - val_loss: 1.2051 - learning_rate: 0.0035
# Epoch 11/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - auc: 0.8564 - loss: 0.8752 - val_auc: 0.8766 - val_loss: 0.8341 - learning_rate: 0.0032
# Epoch 12/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8633 - loss: 0.8440 - val_auc: 0.7500 - val_loss: 4.2003 - learning_rate: 0.0028
# Epoch 13/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8626 - loss: 0.8489 - val_auc: 0.8818 - val_loss: 0.8345 - learning_rate: 0.0025
# Epoch 14/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - auc: 0.8723 - loss: 0.8165 - val_auc: 0.8571 - val_loss: 1.3977 - learning_rate: 0.0022
# Epoch 15/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8818 - loss: 0.7850 - val_auc: 0.8620 - val_loss: 1.1380 - learning_rate: 0.0020
# Epoch 16/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.8839 - loss: 0.7782 - val_auc: 0.8696 - val_loss: 0.9340 - learning_rate: 0.0018
# Epoch 17/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - auc: 0.8933 - loss: 0.7509 - val_auc: 0.8607 - val_loss: 1.3457 - learning_rate: 0.0016
# Epoch 18/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9036 - loss: 0.7175 - val_auc: 0.8501 - val_loss: 0.9112 - learning_rate: 0.0014
# Epoch 19/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9092 - loss: 0.6973 - val_auc: 0.8801 - val_loss: 0.9123 - learning_rate: 0.0013
# Epoch 20/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - auc: 0.9170 - loss: 0.6672 - val_auc: 0.8844 - val_loss: 0.8133 - learning_rate: 0.0011
# Epoch 21/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9262 - loss: 0.6311 - val_auc: 0.8764 - val_loss: 1.0247 - learning_rate: 0.0010
# Epoch 22/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9432 - loss: 0.5599 - val_auc: 0.8474 - val_loss: 0.9265 - learning_rate: 8.9125e-04
# Epoch 23/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9453 - loss: 0.5453 - val_auc: 0.8737 - val_loss: 0.8700 - learning_rate: 7.9433e-04
# Epoch 24/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - auc: 0.9547 - loss: 0.4949 - val_auc: 0.7746 - val_loss: 1.1926 - learning_rate: 7.0795e-04
# Epoch 25/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9606 - loss: 0.4631 - val_auc: 0.8084 - val_loss: 1.0546 - learning_rate: 6.3096e-04
# Epoch 26/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - auc: 0.9667 - loss: 0.4254 - val_auc: 0.8544 - val_loss: 1.3838 - learning_rate: 5.6234e-04
# Epoch 27/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - auc: 0.9739 - loss: 0.3776 - val_auc: 0.8853 - val_loss: 0.9581 - learning_rate: 5.0119e-04
# Epoch 28/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - auc: 0.9734 - loss: 0.3769 - val_auc: 0.8617 - val_loss: 0.9478 - learning_rate: 4.4668e-04
# Epoch 29/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - auc: 0.9775 - loss: 0.3459 - val_auc: 0.8816 - val_loss: 0.9882 - learning_rate: 3.9811e-04
# Epoch 30/100
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 16s 61ms/step - auc: 0.9826 - loss: 0.3091 - val_auc: 0.8763 - val_loss: 1.0009 - learning_rate: 3.5481e-04

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Analysis  🌟🔻</h1>

# %%
# Loading saved model
model = load_model('alzheimer_model.keras')

# Convert dataset to numpy arrays for evaluation
def dataset_to_numpy(dataset):
    images = []
    labels = []
    for image_batch, label_batch in dataset:
        images.extend(image_batch.numpy())
        labels.extend(label_batch.numpy())
    return np.array(images), np.array(labels)

val_images, val_labels = dataset_to_numpy(val_ds)
val_images = val_images / 255.0

train_images, train_labels = dataset_to_numpy(train_ds)
train_images = train_images / 255.0


loss, accuracy = model.evaluate(val_images, val_labels)
print("Loss of the model is - ", loss)
print("Accuracy of the model is - ", accuracy * 100, "%")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - auc: 0.3451 - loss: 324.5282
# Loss of the model is -  330.48626708984375
# Accuracy of the model is -  34.11765098571777 %

# %%
# Save the history
with open('training_history.pkl', 'wb') as file:
    pickle.dump(history.history, file)
    
    
# Load the training history
with open('training_history.pkl', 'rb') as file:
    history = pickle.load(file)

# %%
# Extract the data
acc = history['auc']
val_acc = history['val_auc']
loss = history['loss']
val_loss = history['val_loss']
epochs = range(len(acc))

# Plot accuracy
fig = plt.figure(figsize=(13,7))
plt.title("training vs testing acuuracy")
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.legend(loc='upper left')
plt.show()

# Plot loss
fig = plt.figure(figsize=(13,7))
plt.title("training vs testing loss")
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.legend(loc='upper left')
plt.show()

# %%
# predict the test images
predictions_prob = model.predict(val_images)
predictions = (predictions_prob > 0.5).astype(int)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step

# %%
print(classification_report(val_labels, predictions, target_names = ['MildDemented (Class 0)','ModerateDemented (Class 1)','NonDemented (Class 3)','VeryMildDemented (Class 4)']))
# Out:
#                             precision    recall  f1-score   support
#
#     MildDemented (Class 0)       0.00      0.00      0.00        28
# ModerateDemented (Class 1)       0.01      1.00      0.02         3
#      NonDemented (Class 3)       0.00      0.00      0.00       143
# VeryMildDemented (Class 4)       0.00      0.00      0.00        81
#
#                  micro avg       0.01      0.01      0.01       255
#                  macro avg       0.00      0.25      0.01       255
#               weighted avg       0.00      0.01      0.00       255
#                samples avg       0.01      0.01      0.01       255

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExaWFsMmxudnF2dm84aGs5NW9lcW9zaXdvM3N6eW55YzY4cjc5bm94MiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/smaaKxR6ZrQYQxHFfA/giphy.gif">

# %% [markdown]
#  <div align="center">
#   <a href="mailto:hassaneskikri@gmail.com">
#     <img src="https://img.shields.io/badge/Gmail-333333?style=for-the-badge&logo=gmail&logoColor=red" />
#   </a>
#   <a href="https://www.linkedin.com/in/hassane-skikri-3224bb255/" target="_blank">
#     <img src="https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white" target="_blank" />
#   </a>
#   <a href="https://hassaneskikri.github.io/skikriPortfolio/" target="_blank">
#      <img src="https://img.shields.io/badge/Portfolio-FF5722?style=for-the-badge&logo=todoist&logoColor=white" target="_blank" />
#   </a>
#    <a href="https://medium.com/@Hassane_01" target="_blank">
#     <img src="https://img.shields.io/badge/Medium-12100E?style=for-the-badge&logo=medium&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://www.kaggle.com/hassaneskikri" target="_blank">
#     <img src="https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&logo=Kaggle&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://github.com/HassaneSkikri" target="_blank">
#     <img src="https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white" target="_blank" />
#   </a>
